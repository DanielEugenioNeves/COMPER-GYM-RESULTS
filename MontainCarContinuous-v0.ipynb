# %%
import matplotlib.pyplot as plt
import pandas as pd
import json
import os
import seaborn as sns
from numpy import median
import numpy as np
# %matplotlib inline

# %%
env='MontainCarContinuous-v0'

# %%
# !echo $PYTHONPATH
# Out:
# /home/daniel/COMPER-GYM-RESULTS

# %%
df_comper = pd.DataFrame()
for i in range(1,6):
  path ='COMPER_DDPG/data/'+env+'/train/trial'+str(i)+'/progress.json'
  aux = pd.read_json(path,lines=True)    
  df_comper = pd.concat([df_comper,aux])
df_comper["Method"]="COMPER"
#df_comper = df_comper.set_index(["Trial"])

print(df_comper.shape)
# Out:
# (1270, 17)

# %%
df_ddpg = pd.DataFrame()
for i in range(1,6):
  path ='DPPG/data/'+env+'/train/trial'+str(i)+'/progress.json'
  aux = pd.read_json(path,lines=True)    
  df_ddpg = pd.concat([df_ddpg,aux])
df_ddpg["Method"]="DDPG"
#df_ddpg = df_ddpg.set_index(["Trial"])
print(df_ddpg.shape)

#/home/daniel/COMPER-GYM-RESULTS/DPPG/data/Ant-v4/train/trial1/progress.json
# Out:
# (1270, 17)

# %%
df_comper.head(15)
# Out:
#     Trial  LogCount                      Task                 Time  TotalItr  \
# 0       1         1  MountainCarContinuous-v0  08-05-2023 17:38:19       200
# 1       1         2  MountainCarContinuous-v0  08-05-2023 17:38:26       400
# 2       1         3  MountainCarContinuous-v0  08-05-2023 17:38:34       600
# 3       1         4  MountainCarContinuous-v0  08-05-2023 17:38:41       800
# 4       1         5  MountainCarContinuous-v0  08-05-2023 17:38:48      1000
# 5       1         6  MountainCarContinuous-v0  08-05-2023 17:38:55      1200
# 6       1         7  MountainCarContinuous-v0  08-05-2023 17:39:03      1400
# 7       1         8  MountainCarContinuous-v0  08-05-2023 17:39:10      1600
# 8       1         9  MountainCarContinuous-v0  08-05-2023 17:39:18      1800
# 9       1        10  MountainCarContinuous-v0  08-05-2023 17:39:25      2000
# 10      1        11  MountainCarContinuous-v0  08-05-2023 17:39:32      2200
# 11      1        12  MountainCarContinuous-v0  08-05-2023 17:39:40      2400
# 12      1        13  MountainCarContinuous-v0  08-05-2023 17:39:48      2600
# 13      1        14  MountainCarContinuous-v0  08-05-2023 17:39:55      2800
# 14      1        15  MountainCarContinuous-v0  08-05-2023 17:40:03      3000
#
#     TMCount  RTMCount         e  Ep  EpItr   Done     EpRew     AvgEp  \
# 0       201         0  0.009941   1    201  False -0.286961 -0.286961
# 1       401         0  0.019882   1    401  False -0.806300 -0.546631
# 2       601         0  0.029822   1    601  False -3.494675 -1.529312
# 3       801         0  0.039763   1    801  False -4.116832 -2.176192
# 4      1001         0  0.049704   2      2  False -0.014146 -1.743783
# 5      1201         0  0.059645   2    202  False -1.146818 -1.644289
# 6      1401         0  0.069586   2    402  False -4.779802 -2.092219
# 7      1601         0  0.079526   2    602  False -8.190930 -2.854558
# 8      1801         0  0.089467   2    802  False -8.522040 -3.484278
# 9      2001         0  0.099408   3      3  False -0.004883 -3.136339
# 10     2201         0  0.109349   3    203  False -0.447128 -2.891865
# 11     2401         0  0.119290   3    403  False -1.151567 -2.746840
# 12     2601         0  0.129230   3    603  False -1.378155 -2.641557
# 13     2801         0  0.139171   3    803  False -1.560948 -2.564370
# 14     3001         0  0.149112   4      4  False -0.004711 -2.393726
#
#     Avg100Ep  AvgLast50Ep  AvgLast10Ep  Method
# 0  -0.286961    -0.286961    -0.286961  COMPER
# 1  -0.546631    -0.546631    -0.546631  COMPER
# 2  -1.529312    -1.529312    -1.529312  COMPER
# 3  -2.176192    -2.176192    -2.176192  COMPER
# 4  -1.743783    -1.743783    -1.743783  COMPER
# 5  -1.644289    -1.644289    -1.644289  COMPER
# 6  -2.092219    -2.092219    -2.092219  COMPER
# 7  -2.854558    -2.854558    -2.854558  COMPER
# 8  -3.484278    -3.484278    -3.484278  COMPER
# 9  -3.136339    -3.136339    -3.136339  COMPER
# 10 -2.891865    -2.891865    -3.152355  COMPER
# 11 -2.746840    -2.746840    -3.186882  COMPER
# 12 -2.641557    -2.641557    -2.975230  COMPER
# 13 -2.564370    -2.564370    -2.719642  COMPER
# 14 -2.393726    -2.393726    -2.718698  COMPER

# %%
df_ddpg.head(15)
# Out:
#     Trial  LogCount                      Task                 Time  TotalItr  \
# 0       1         1  MountainCarContinuous-v0  08-05-2023 17:38:19       200
# 1       1         2  MountainCarContinuous-v0  08-05-2023 17:38:26       400
# 2       1         3  MountainCarContinuous-v0  08-05-2023 17:38:34       600
# 3       1         4  MountainCarContinuous-v0  08-05-2023 17:38:41       800
# 4       1         5  MountainCarContinuous-v0  08-05-2023 17:38:48      1000
# 5       1         6  MountainCarContinuous-v0  08-05-2023 17:38:55      1200
# 6       1         7  MountainCarContinuous-v0  08-05-2023 17:39:03      1400
# 7       1         8  MountainCarContinuous-v0  08-05-2023 17:39:10      1600
# 8       1         9  MountainCarContinuous-v0  08-05-2023 17:39:18      1800
# 9       1        10  MountainCarContinuous-v0  08-05-2023 17:39:25      2000
# 10      1        11  MountainCarContinuous-v0  08-05-2023 17:39:32      2200
# 11      1        12  MountainCarContinuous-v0  08-05-2023 17:39:40      2400
# 12      1        13  MountainCarContinuous-v0  08-05-2023 17:39:48      2600
# 13      1        14  MountainCarContinuous-v0  08-05-2023 17:39:55      2800
# 14      1        15  MountainCarContinuous-v0  08-05-2023 17:40:03      3000
#
#     TMCount  RTMCount         e  Ep  EpItr   Done     EpRew     AvgEp  \
# 0       201         0  0.009941   1    201  False -0.286961 -0.286961
# 1       401         0  0.019882   1    401  False -0.806300 -0.546631
# 2       601         0  0.029822   1    601  False -3.494675 -1.529312
# 3       801         0  0.039763   1    801  False -4.116832 -2.176192
# 4      1001         0  0.049704   2      2  False -0.014146 -1.743783
# 5      1201         0  0.059645   2    202  False -1.146818 -1.644289
# 6      1401         0  0.069586   2    402  False -4.779802 -2.092219
# 7      1601         0  0.079526   2    602  False -8.190930 -2.854558
# 8      1801         0  0.089467   2    802  False -8.522040 -3.484278
# 9      2001         0  0.099408   3      3  False -0.004883 -3.136339
# 10     2201         0  0.109349   3    203  False -0.447128 -2.891865
# 11     2401         0  0.119290   3    403  False -1.151567 -2.746840
# 12     2601         0  0.129230   3    603  False -1.378155 -2.641557
# 13     2801         0  0.139171   3    803  False -1.560948 -2.564370
# 14     3001         0  0.149112   4      4  False -0.004711 -2.393726
#
#     Avg100Ep  AvgLast50Ep  AvgLast10Ep Method
# 0  -0.286961    -0.286961    -0.286961   DDPG
# 1  -0.546631    -0.546631    -0.546631   DDPG
# 2  -1.529312    -1.529312    -1.529312   DDPG
# 3  -2.176192    -2.176192    -2.176192   DDPG
# 4  -1.743783    -1.743783    -1.743783   DDPG
# 5  -1.644289    -1.644289    -1.644289   DDPG
# 6  -2.092219    -2.092219    -2.092219   DDPG
# 7  -2.854558    -2.854558    -2.854558   DDPG
# 8  -3.484278    -3.484278    -3.484278   DDPG
# 9  -3.136339    -3.136339    -3.136339   DDPG
# 10 -2.891865    -2.891865    -3.152355   DDPG
# 11 -2.746840    -2.746840    -3.186882   DDPG
# 12 -2.641557    -2.641557    -2.975230   DDPG
# 13 -2.564370    -2.564370    -2.719642   DDPG
# 14 -2.393726    -2.393726    -2.718698   DDPG

# %%
df=pd.concat([df_comper,df_ddpg])
df.head()
# Out:
#    Trial  LogCount                      Task                 Time  TotalItr  \
# 0      1         1  MountainCarContinuous-v0  08-05-2023 17:38:19       200
# 1      1         2  MountainCarContinuous-v0  08-05-2023 17:38:26       400
# 2      1         3  MountainCarContinuous-v0  08-05-2023 17:38:34       600
# 3      1         4  MountainCarContinuous-v0  08-05-2023 17:38:41       800
# 4      1         5  MountainCarContinuous-v0  08-05-2023 17:38:48      1000
#
#    TMCount  RTMCount         e  Ep  EpItr   Done     EpRew     AvgEp  \
# 0      201         0  0.009941   1    201  False -0.286961 -0.286961
# 1      401         0  0.019882   1    401  False -0.806300 -0.546631
# 2      601         0  0.029822   1    601  False -3.494675 -1.529312
# 3      801         0  0.039763   1    801  False -4.116832 -2.176192
# 4     1001         0  0.049704   2      2  False -0.014146 -1.743783
#
#    Avg100Ep  AvgLast50Ep  AvgLast10Ep  Method
# 0 -0.286961    -0.286961    -0.286961  COMPER
# 1 -0.546631    -0.546631    -0.546631  COMPER
# 2 -1.529312    -1.529312    -1.529312  COMPER
# 3 -2.176192    -2.176192    -2.176192  COMPER
# 4 -1.743783    -1.743783    -1.743783  COMPER

# %%
df.tail()
# Out:
#      Trial  LogCount                      Task                 Time  TotalItr  \
# 249      5       250  MountainCarContinuous-v0  08-05-2023 21:19:52     50000
# 250      5       251  MountainCarContinuous-v0  08-05-2023 21:20:15     50200
# 251      5       252  MountainCarContinuous-v0  08-05-2023 21:20:29     50400
# 252      5       253  MountainCarContinuous-v0  08-05-2023 21:20:42     50600
# 253      5       254  MountainCarContinuous-v0  08-05-2023 21:20:55     50800
#
#      TMCount  RTMCount      e  Ep  EpItr   Done      EpRew     AvgEp  \
# 249    50001         0  0.999  51     51  False  -1.225082 -4.168941
# 250    50201         0  0.999  51    251  False  -7.602292 -4.182620
# 251    50401         0  0.999  51    451  False  -9.872390 -4.205199
# 252    50601         0  0.999  51    651  False -16.769893 -4.254861
# 253    50801         0  0.999  51    851  False -22.815581 -4.327935
#
#      Avg100Ep  AvgLast50Ep  AvgLast10Ep Method
# 249 -4.518099    -3.768669    -0.912621   DDPG
# 250 -4.487245    -3.846775    -1.584633   DDPG
# 251 -4.402746    -3.858532    -2.448565   DDPG
# 252 -4.334292    -3.980997    -3.992302   DDPG
# 253 -4.309496    -4.184920    -6.106394   DDPG

# %%
fig, axs = plt.subplots(nrows=2,ncols=2)
fig.set_figwidth(15)
fig.set_figheight(10)
sns.scatterplot(data=df, x="TotalItr", y="EpRew", hue="Method",ax=axs[0][0])
sns.scatterplot(data=df, x="TotalItr", y="Avg100Ep", hue="Method",ax=axs[0][1])
sns.scatterplot(data=df, x="TotalItr", y="AvgLast50Ep", hue="Method",ax=axs[1][0])
sns.scatterplot(data=df, x="TotalItr", y="AvgLast10Ep", hue="Method",ax=axs[1][1])
# Out:
# <Axes: xlabel='TotalItr', ylabel='AvgLast10Ep'>

# %%
fig, axs = plt.subplots(nrows=2,ncols=2)
fig.set_figwidth(15)
fig.set_figheight(10)
sns.lineplot(data=df, x="TotalItr", y="EpRew",hue='Method',ax=axs[0][0])
sns.lineplot(data=df, x="TotalItr", y="Avg100Ep",hue="Method",ax=axs[0][1])
sns.lineplot(data=df, x="TotalItr", y="AvgLast50Ep",hue="Method",ax=axs[1][0])
sns.lineplot(data=df, x="TotalItr", y="AvgLast10Ep",hue="Method",ax=axs[1][1])
# Out:
# <Axes: xlabel='TotalItr', ylabel='AvgLast10Ep'>

# %%
path ='COMPER_DDPG/data/'+env+'/eval/progress.json'
df_comper_eval = pd.read_json(path,lines=True)
df_comper_eval["Method"]="COMPER"
#df_comper_eval=df_comper_eval[df_comper_eval["Trial"]==1]
print(df_comper_eval.shape)
df_comper_eval.head()
# Out:
# (41, 6)
#    Trial                 Time                      Task    Int  EvalAvgRew  \
# 0      2  27-04-2023 15:59:09  MountainCarContinuous-v0   5000   -0.131704
# 1      2  27-04-2023 19:11:05  MountainCarContinuous-v0  10000   -0.131706
# 2      2  27-04-2023 22:19:58  MountainCarContinuous-v0  15000   -0.010259
# 3      2  28-04-2023 01:33:54  MountainCarContinuous-v0  20000   -0.111199
# 4      2  28-04-2023 04:47:53  MountainCarContinuous-v0  25000   -0.111197
#
#    Method
# 0  COMPER
# 1  COMPER
# 2  COMPER
# 3  COMPER
# 4  COMPER

# %%
df_comper_eval.describe()
# Out:
#            Trial           Int  EvalAvgRew
# count  41.000000     41.000000   41.000000
# mean    3.487805  26951.219512   -0.041560
# std     1.120758  14785.045180    0.051133
# min     2.000000   5000.000000   -0.150562
# 25%     3.000000  15000.000000   -0.111150
# 50%     3.000000  25000.000000   -0.012986
# 75%     4.000000  40000.000000   -0.003167
# max     5.000000  50000.000000   -0.000153

# %%
path ='DPPG/data/'+env+'/eval/progress.json'
df_ddpg_eval = pd.read_json(path,lines=True)
#df_ddpg_eval=df_ddpg_eval[df_ddpg_eval["Trial"]==1]
df_ddpg_eval["Method"]="DDPG"
print(df_ddpg_eval.shape)
df_ddpg_eval.head()
# Out:
# (50, 6)
#    Trial                 Time                      Task    Int  EvalAvgRew  \
# 0      1  08-05-2023 17:41:39  MountainCarContinuous-v0   5000   -0.024605
# 1      1  08-05-2023 17:45:16  MountainCarContinuous-v0  10000   -0.006320
# 2      1  08-05-2023 17:49:11  MountainCarContinuous-v0  15000   -0.006478
# 3      1  08-05-2023 17:53:18  MountainCarContinuous-v0  20000   -0.000499
# 4      1  08-05-2023 17:57:31  MountainCarContinuous-v0  25000   -0.000567
#
#   Method
# 0   DDPG
# 1   DDPG
# 2   DDPG
# 3   DDPG
# 4   DDPG

# %%
df_ddpg_eval.describe()
# Out:
#            Trial           Int    EvalAvgRew
# count  50.000000     50.000000  5.000000e+01
# mean    3.000000  27500.000000 -3.918835e-03
# std     1.428571  14507.211437  7.402510e-03
# min     1.000000   5000.000000 -4.527408e-02
# 25%     2.000000  15000.000000 -4.472004e-03
# 50%     3.000000  27500.000000 -1.319223e-03
# 75%     4.000000  40000.000000 -2.486567e-04
# max     5.000000  50000.000000 -5.603678e-08

# %%
df_eval=pd.concat([df_comper_eval,df_ddpg_eval])
df_eval.rename(columns = {'Int':'Itr'}, inplace = True)

# %%
sns.lineplot(data=df_eval, x="Itr", y="EvalAvgRew",hue='Method')
# Out:
# <Axes: xlabel='Itr', ylabel='EvalAvgRew'>
