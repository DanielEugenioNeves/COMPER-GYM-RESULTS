# %%
import matplotlib.pyplot as plt
import pandas as pd
import json
import os
import seaborn as sns
from numpy import median
import numpy as np
# %matplotlib inline

# %%
env='MountainCarContinuous-v0'

# %%
# !echo $PYTHONPATH
# Out:
# /home/daniel/COMPER-GYM-RESULTS

# %%
df_comper = pd.DataFrame()
for i in range(1,6):
  path ='COMPER_DDPG/data/'+env+'/train/trial'+str(i)+'/progress.json'
  aux = pd.read_json(path,lines=True)    
  df_comper = pd.concat([df_comper,aux])
df_comper["Method"]="COMPER"
#df_comper = df_comper.set_index(["Trial"])

print(df_comper.shape)
# Out:
# (30248, 17)

# %%
df_ddpg = pd.DataFrame()
for i in range(1,6):
  path ='DPPG/data/'+env+'/train/trial'+str(i)+'/progress.json'
  aux = pd.read_json(path,lines=True)    
  df_ddpg = pd.concat([df_ddpg,aux])
df_ddpg["Method"]="DDPG"
#df_ddpg = df_ddpg.set_index(["Trial"])
print(df_ddpg.shape)

#/home/daniel/COMPER-GYM-RESULTS/DPPG/data/Ant-v4/train/trial1/progress.json
# Out:
# (1505, 17)

# %%
df_comper.head(15)
# Out:
#     Trial  LogCount                      Task                 Time  TotalItr  \
# 0       1         1  MountainCarContinuous-v0  28-07-2023 15:14:04       200
# 1       1         2  MountainCarContinuous-v0  28-07-2023 15:19:26       400
# 2       1         3  MountainCarContinuous-v0  28-07-2023 15:24:52       600
# 3       1         4  MountainCarContinuous-v0  28-07-2023 15:30:27       800
# 4       1         5  MountainCarContinuous-v0  28-07-2023 15:35:55       999
# 5       1         6  MountainCarContinuous-v0  28-07-2023 15:35:57      1000
# 6       1         7  MountainCarContinuous-v0  28-07-2023 15:41:22      1200
# 7       1         8  MountainCarContinuous-v0  28-07-2023 15:46:54      1400
# 8       1         9  MountainCarContinuous-v0  28-07-2023 15:52:29      1600
# 9       1        10  MountainCarContinuous-v0  28-07-2023 15:58:07      1800
# 10      1        11  MountainCarContinuous-v0  28-07-2023 16:03:35      1998
# 11      1        12  MountainCarContinuous-v0  28-07-2023 16:03:39      2000
# 12      1        13  MountainCarContinuous-v0  28-07-2023 16:09:11      2200
# 13      1        14  MountainCarContinuous-v0  28-07-2023 16:14:42      2400
# 14      1        15  MountainCarContinuous-v0  28-07-2023 16:14:43      2401
#
#     TMCount  RTMCount         e  Ep  EpItr   Done      EpRew     AvgEp  \
# 0         0       166  0.009941   1    201  False  -1.470786 -1.470786
# 1         0       311  0.019882   1    401  False  -1.984202 -1.727494
# 2         0       455  0.029822   1    601  False  -5.005238 -2.820076
# 3         0       592  0.039763   1    801  False  -7.342238 -3.950616
# 4         0       769  0.049654   1   1000   True  -8.396679 -4.839829
# 5         0       770  0.049704   2      2  False  -0.004779 -4.033987
# 6         0       926  0.059645   2    202  False  -0.138645 -3.477510
# 7         0      1089  0.069586   2    402  False  -0.399704 -3.092784
# 8         0      1272  0.079526   2    602  False  -0.960698 -2.855886
# 9         0      1466  0.089467   2    802  False  -4.126930 -2.982990
# 10        0      1647  0.099309   2   1000   True -15.344122 -4.106729
# 11        0      1649  0.099408   3      3  False  -0.119648 -3.774472
# 12        0      1844  0.109349   3    203  False  -3.319213 -3.739453
# 13        0      2038  0.119290   3    403  False  -8.541484 -4.082455
# 14        0      2039  0.119339   3    404   True  91.448577  2.286281
#
#     Avg100Ep  AvgLast50Ep  AvgLast10Ep  Method
# 0  -1.470786    -1.470786    -1.470786  COMPER
# 1  -1.727494    -1.727494    -1.727494  COMPER
# 2  -2.820076    -2.820076    -2.820076  COMPER
# 3  -3.950616    -3.950616    -3.950616  COMPER
# 4  -4.839829    -4.839829    -4.839829  COMPER
# 5  -4.033987    -4.033987    -4.033987  COMPER
# 6  -3.477510    -3.477510    -3.477510  COMPER
# 7  -3.092784    -3.092784    -3.092784  COMPER
# 8  -2.855886    -2.855886    -2.855886  COMPER
# 9  -2.982990    -2.982990    -2.982990  COMPER
# 10 -4.106729    -4.106729    -4.370324  COMPER
# 11 -3.774472    -3.774472    -4.183868  COMPER
# 12 -3.739453    -3.739453    -4.015266  COMPER
# 13 -4.082455    -4.082455    -4.135190  COMPER
# 14  2.286281     2.286281     5.849335  COMPER

# %%
df_ddpg.head(15)
# Out:
#     Trial  LogCount                      Task                 Time  TotalItr  \
# 0       1         1  MountainCarContinuous-v0  20-07-2023 13:50:54       200
# 1       1         2  MountainCarContinuous-v0  20-07-2023 13:51:11       400
# 2       1         3  MountainCarContinuous-v0  20-07-2023 13:51:29       600
# 3       1         4  MountainCarContinuous-v0  20-07-2023 13:51:47       800
# 4       1         5  MountainCarContinuous-v0  20-07-2023 13:52:04       999
# 5       1         6  MountainCarContinuous-v0  20-07-2023 13:52:04      1000
# 6       1         7  MountainCarContinuous-v0  20-07-2023 13:52:21      1200
# 7       1         8  MountainCarContinuous-v0  20-07-2023 13:52:39      1400
# 8       1         9  MountainCarContinuous-v0  20-07-2023 13:52:56      1600
# 9       1        10  MountainCarContinuous-v0  20-07-2023 13:53:13      1800
# 10      1        11  MountainCarContinuous-v0  20-07-2023 13:53:30      1998
# 11      1        12  MountainCarContinuous-v0  20-07-2023 13:53:30      2000
# 12      1        13  MountainCarContinuous-v0  20-07-2023 13:53:47      2200
# 13      1        14  MountainCarContinuous-v0  20-07-2023 13:54:04      2400
# 14      1        15  MountainCarContinuous-v0  20-07-2023 13:54:22      2600
#
#     TMCount  RTMCount         e  Ep  EpItr   Done     EpRew     AvgEp  \
# 0       127         0  0.009941   1    201  False -2.350934 -2.350934
# 1       206         0  0.019882   1    401  False -3.499505 -2.925220
# 2       301         0  0.029822   1    601  False -6.686414 -4.178951
# 3       358         0  0.039763   1    801  False -7.524165 -5.015255
# 4       445         0  0.049654   1   1000   True -8.279169 -5.668037
# 5       446         0  0.049704   2      2  False -0.009067 -4.724876
# 6       603         0  0.059645   2    202  False -0.424398 -4.110522
# 7       783         0  0.069586   2    402  False -0.808439 -3.697761
# 8       957         0  0.079526   2    602  False -0.958821 -3.393435
# 9      1137         0  0.089467   2    802  False -1.996355 -3.253727
# 10     1312         0  0.099309   2   1000   True -5.676687 -3.473996
# 11     1314         0  0.099408   3      3  False -0.011654 -3.185467
# 12     1476         0  0.109349   3    203  False -1.424695 -3.050023
# 13     1633         0  0.119290   3    403  False -3.041934 -3.049446
# 14     1779         0  0.129230   3    603  False -3.832454 -3.101646
#
#     Avg100Ep  AvgLast50Ep  AvgLast10Ep Method
# 0  -2.350934    -2.350934    -2.350934   DDPG
# 1  -2.925220    -2.925220    -2.925220   DDPG
# 2  -4.178951    -4.178951    -4.178951   DDPG
# 3  -5.015255    -5.015255    -5.015255   DDPG
# 4  -5.668037    -5.668037    -5.668037   DDPG
# 5  -4.724876    -4.724876    -4.724876   DDPG
# 6  -4.110522    -4.110522    -4.110522   DDPG
# 7  -3.697761    -3.697761    -3.697761   DDPG
# 8  -3.393435    -3.393435    -3.393435   DDPG
# 9  -3.253727    -3.253727    -3.253727   DDPG
# 10 -3.473996    -3.473996    -3.586302   DDPG
# 11 -3.185467    -3.185467    -3.237517   DDPG
# 12 -3.050023    -3.050023    -2.711345   DDPG
# 13 -3.049446    -3.049446    -2.263122   DDPG
# 14 -3.101646    -3.101646    -1.818451   DDPG

# %%
df=pd.concat([df_comper,df_ddpg])
df.head()
# Out:
#    Trial  LogCount                      Task                 Time  TotalItr  \
# 0      1         1  MountainCarContinuous-v0  28-07-2023 15:14:04       200
# 1      1         2  MountainCarContinuous-v0  28-07-2023 15:19:26       400
# 2      1         3  MountainCarContinuous-v0  28-07-2023 15:24:52       600
# 3      1         4  MountainCarContinuous-v0  28-07-2023 15:30:27       800
# 4      1         5  MountainCarContinuous-v0  28-07-2023 15:35:55       999
#
#    TMCount  RTMCount         e  Ep  EpItr   Done     EpRew     AvgEp  \
# 0        0       166  0.009941   1    201  False -1.470786 -1.470786
# 1        0       311  0.019882   1    401  False -1.984202 -1.727494
# 2        0       455  0.029822   1    601  False -5.005238 -2.820076
# 3        0       592  0.039763   1    801  False -7.342238 -3.950616
# 4        0       769  0.049654   1   1000   True -8.396679 -4.839829
#
#    Avg100Ep  AvgLast50Ep  AvgLast10Ep  Method
# 0 -1.470786    -1.470786    -1.470786  COMPER
# 1 -1.727494    -1.727494    -1.727494  COMPER
# 2 -2.820076    -2.820076    -2.820076  COMPER
# 3 -3.950616    -3.950616    -3.950616  COMPER
# 4 -4.839829    -4.839829    -4.839829  COMPER

# %%
df.tail()
# Out:
#      Trial  LogCount                      Task                 Time  TotalItr  \
# 296      5       297  MountainCarContinuous-v0  20-07-2023 20:05:39     49600
# 297      5       298  MountainCarContinuous-v0  20-07-2023 20:05:58     49800
# 298      5       299  MountainCarContinuous-v0  20-07-2023 20:06:12     49950
# 299      5       300  MountainCarContinuous-v0  20-07-2023 20:06:17     50000
# 300      5       301  MountainCarContinuous-v0  20-07-2023 20:06:17     50001
#
#      TMCount  RTMCount      e  Ep  EpItr   Done      EpRew     AvgEp  \
# 296    14221         0  0.999  50    650  False  -9.134983 -6.674483
# 297    14240         0  0.999  50    850  False -10.596937 -6.687646
# 298    14249         0  0.999  50   1000   True -11.254493 -6.702920
# 299    14249         0  0.999  51     51   True  -0.106347 -6.680931
# 300    14249         0  0.999  52      2   True  -0.001552 -6.658740
#
#      Avg100Ep  AvgLast50Ep  AvgLast10Ep Method
# 296 -5.784190    -7.323435    -3.983465   DDPG
# 297 -5.887863    -7.396878    -5.037305   DDPG
# 298 -5.990816    -7.474999    -6.136666   DDPG
# 299 -5.965931    -7.326414    -6.050669   DDPG
# 300 -5.876579    -7.161006    -5.859688   DDPG

# %%
fig, axs = plt.subplots(nrows=2,ncols=2)
fig.set_figwidth(15)
fig.set_figheight(10)
sns.lineplot(data=df, x="TotalItr", y="EpRew",hue='Method',ax=axs[0][0])
sns.lineplot(data=df, x="TotalItr", y="Avg100Ep",hue="Method",ax=axs[0][1])
sns.lineplot(data=df, x="TotalItr", y="AvgLast50Ep",hue="Method",ax=axs[1][0])
sns.lineplot(data=df, x="TotalItr", y="AvgLast10Ep",hue="Method",ax=axs[1][1])
# Out:
# <Axes: xlabel='TotalItr', ylabel='AvgLast10Ep'>

# %%
fig, axs = plt.subplots(nrows=2,ncols=2)
fig.set_figwidth(15)
fig.set_figheight(10)
sns.lineplot(data=df, x="TotalItr", y="EpRew",hue='Method',ax=axs[0][0])
sns.lineplot(data=df, x="TotalItr", y="Avg100Ep",hue="Method",ax=axs[0][1])
sns.lineplot(data=df, x="TotalItr", y="AvgLast50Ep",hue="Method",ax=axs[1][0])
sns.lineplot(data=df, x="TotalItr", y="AvgLast10Ep",hue="Method",ax=axs[1][1])
# Out:
# <Axes: xlabel='TotalItr', ylabel='AvgLast10Ep'>

# %%
path ='COMPER_DDPG/data/'+env+'/eval/progress.json'
df_comper_eval = pd.read_json(path,lines=True)
df_comper_eval["Method"]="COMPER"
#df_comper_eval=df_comper_eval[df_comper_eval["Trial"]==1]
print(df_comper_eval.shape)
df_comper_eval.head()
# Out:
# (50, 6)
#    Trial                 Time                      Task    Int  EvalAvgRew  \
# 0      1  28-07-2023 17:26:51  MountainCarContinuous-v0   5000   -0.461284
# 1      1  28-07-2023 19:44:17  MountainCarContinuous-v0  10000   -0.549898
# 2      1  28-07-2023 22:02:48  MountainCarContinuous-v0  15000   -0.549778
# 3      1  29-07-2023 00:20:21  MountainCarContinuous-v0  20000   -0.549870
# 4      1  29-07-2023 02:34:44  MountainCarContinuous-v0  25000   -0.018828
#
#    Method
# 0  COMPER
# 1  COMPER
# 2  COMPER
# 3  COMPER
# 4  COMPER

# %%
df_comper_eval.describe()
# Out:
#            Trial           Int  EvalAvgRew
# count  50.000000     50.000000   50.000000
# mean    3.000000  27500.000000   -0.067812
# std     1.428571  14507.211437    0.163245
# min     1.000000   5000.000000   -0.549975
# 25%     2.000000  15000.000000   -0.019801
# 50%     3.000000  27500.000000   -0.002685
# 75%     4.000000  40000.000000   -0.000466
# max     5.000000  50000.000000   -0.000002

# %%
path ='DPPG/data/'+env+'/eval/progress.json'
df_ddpg_eval = pd.read_json(path,lines=True)
#df_ddpg_eval=df_ddpg_eval[df_ddpg_eval["Trial"]==1]
df_ddpg_eval["Method"]="DDPG"
print(df_ddpg_eval.shape)
df_ddpg_eval.head()
# Out:
# (50, 6)
#    Trial                 Time                      Task    Int  EvalAvgRew  \
# 0      1  20-07-2023 13:57:55  MountainCarContinuous-v0   5000   -0.000244
# 1      1  20-07-2023 14:05:15  MountainCarContinuous-v0  10000   -0.001033
# 2      1  20-07-2023 14:12:40  MountainCarContinuous-v0  15000   -0.000002
# 3      1  20-07-2023 14:20:06  MountainCarContinuous-v0  20000   -0.000123
# 4      1  20-07-2023 14:27:34  MountainCarContinuous-v0  25000   -0.000004
#
#   Method
# 0   DDPG
# 1   DDPG
# 2   DDPG
# 3   DDPG
# 4   DDPG

# %%
df_ddpg_eval.describe()
# Out:
#            Trial           Int    EvalAvgRew
# count  50.000000     50.000000  5.000000e+01
# mean    3.000000  27500.000000 -1.266132e-03
# std     1.428571  14507.211437  3.488318e-03
# min     1.000000   5000.000000 -1.997005e-02
# 25%     2.000000  15000.000000 -8.665582e-04
# 50%     3.000000  27500.000000 -2.139040e-04
# 75%     4.000000  40000.000000 -3.626127e-05
# max     5.000000  50000.000000 -9.490764e-07

# %%
df_eval=pd.concat([df_comper_eval,df_ddpg_eval])
df_eval.rename(columns = {'Int':'Itr'}, inplace = True)

# %%
sns.lineplot(data=df_eval, x="Itr", y="EvalAvgRew",hue='Method')
# Out:
# <Axes: xlabel='Itr', ylabel='EvalAvgRew'>
