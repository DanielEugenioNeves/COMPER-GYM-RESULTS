# %% [markdown]
# ## FALTAM LOGS DE 2 EXPERIMENTOS PARA O COMPER-DDPG

# %%
import matplotlib.pyplot as plt
import pandas as pd
import json
import os
import seaborn as sns
from numpy import median
import numpy as np
# %matplotlib inline

# %%
env='InvertedDoublePendulum-v4'

# %%
# !echo $PYTHONPATH
# Out:
# /home/daniel/COMPER-GYM-RESULTS

# %%
df_comper = pd.DataFrame()
for i in range(1,4):
  path ='COMPER_DDPG/data/'+env+'/train/trial'+str(i)+'/progress.json'
  aux = pd.read_json(path,lines=True)    
  df_comper = pd.concat([df_comper,aux])
df_comper["Method"]="COMPER"
#df_comper = df_comper.set_index(["Trial"])

print(df_comper.shape)
# Out:
# (139025, 17)

# %%
df_ddpg = pd.DataFrame()
for i in range(1,6):
  path ='DPPG/data/'+env+'/train/trial'+str(i)+'/progress.json'
  aux = pd.read_json(path,lines=True)    
  df_ddpg = pd.concat([df_ddpg,aux])
df_ddpg["Method"]="DDPG"
#df_ddpg = df_ddpg.set_index(["Trial"])
print(df_ddpg.shape)

#/home/daniel/COMPER-GYM-RESULTS/DPPG/data/Ant-v4/train/trial1/progress.json
# Out:
# (227066, 17)

# %%
df_comper.head(15)
# Out:
#     Trial  LogCount                       Task                 Time  TotalItr  \
# 0       1         1  InvertedDoublePendulum-v4  25-07-2023 16:18:34         9
# 1       1         2  InvertedDoublePendulum-v4  25-07-2023 16:18:35        10
# 2       1         3  InvertedDoublePendulum-v4  25-07-2023 16:18:35        11
# 3       1         4  InvertedDoublePendulum-v4  25-07-2023 16:18:36        12
# 4       1         5  InvertedDoublePendulum-v4  25-07-2023 16:18:37        13
# 5       1         6  InvertedDoublePendulum-v4  25-07-2023 16:18:37        14
# 6       1         7  InvertedDoublePendulum-v4  25-07-2023 16:18:38        15
# 7       1         8  InvertedDoublePendulum-v4  25-07-2023 16:18:39        16
# 8       1         9  InvertedDoublePendulum-v4  25-07-2023 16:18:40        17
# 9       1        10  InvertedDoublePendulum-v4  25-07-2023 16:18:40        18
# 10      1        11  InvertedDoublePendulum-v4  25-07-2023 16:18:41        19
# 11      1        12  InvertedDoublePendulum-v4  25-07-2023 16:18:42        20
# 12      1        13  InvertedDoublePendulum-v4  25-07-2023 16:18:43        21
# 13      1        14  InvertedDoublePendulum-v4  25-07-2023 16:18:43        22
# 14      1        15  InvertedDoublePendulum-v4  25-07-2023 16:18:46        25
#
#     TMCount  RTMCount         e  Ep  EpItr  Done       EpRew       AvgEp  \
# 0         0         9  0.000447   1     10  True   82.507769   82.507769
# 1         0        10  0.000497   1     11  True   90.900910   86.704340
# 2         0        11  0.000547   1     12  True   99.042960   90.817213
# 3         0        12  0.000596   1     13  True  106.820898   94.818134
# 4         0        13  0.000646   1     14  True  113.872640   98.629035
# 5         0        14  0.000696   1     15  True  119.384919  102.088349
# 6         0        15  0.000746   1     16  True  121.883043  104.916163
# 7         0        16  0.000795   1     17  True  119.708716  106.765232
# 8         0        17  0.000845   1     18  True  119.705328  108.203020
# 9         0        18  0.000895   1     19  True  120.286414  109.411360
# 10        0        19  0.000944   1     20  True  122.717264  110.620987
# 11        0        20  0.000994   1     21  True  127.518104  112.029080
# 12        0        21  0.001044   1     22  True  134.115046  113.728001
# 13        0        22  0.001093   1     23  True  141.992235  115.746875
# 14        0        25  0.001243   1     26  True  163.998467  118.963648
#
#       Avg100Ep  AvgLast50Ep  AvgLast10Ep  Method
# 0    82.507769    82.507769    82.507769  COMPER
# 1    86.704340    86.704340    86.704340  COMPER
# 2    90.817213    90.817213    90.817213  COMPER
# 3    94.818134    94.818134    94.818134  COMPER
# 4    98.629035    98.629035    98.629035  COMPER
# 5   102.088349   102.088349   102.088349  COMPER
# 6   104.916163   104.916163   104.916163  COMPER
# 7   106.765232   106.765232   106.765232  COMPER
# 8   108.203020   108.203020   108.203020  COMPER
# 9   109.411360   109.411360   109.411360  COMPER
# 10  110.620987   110.620987   113.432309  COMPER
# 11  112.029080   112.029080   117.094029  COMPER
# 12  113.728001   113.728001   120.601237  COMPER
# 13  115.746875   115.746875   124.118371  COMPER
# 14  118.963648   118.963648   129.130954  COMPER

# %%
df_ddpg.head(15)
# Out:
#     Trial  LogCount                       Task                 Time  TotalItr  \
# 0       1         1  InvertedDoublePendulum-v4  16-07-2023 13:31:41         8
# 1       1         2  InvertedDoublePendulum-v4  16-07-2023 13:31:41         9
# 2       1         3  InvertedDoublePendulum-v4  16-07-2023 13:31:41        10
# 3       1         4  InvertedDoublePendulum-v4  16-07-2023 13:31:41        11
# 4       1         5  InvertedDoublePendulum-v4  16-07-2023 13:31:41        12
# 5       1         6  InvertedDoublePendulum-v4  16-07-2023 13:31:41        13
# 6       1         7  InvertedDoublePendulum-v4  16-07-2023 13:31:41        14
# 7       1         8  InvertedDoublePendulum-v4  16-07-2023 13:31:41        15
# 8       1         9  InvertedDoublePendulum-v4  16-07-2023 13:31:41        16
# 9       1        10  InvertedDoublePendulum-v4  16-07-2023 13:31:41        17
# 10      1        11  InvertedDoublePendulum-v4  16-07-2023 13:31:42        18
# 11      1        12  InvertedDoublePendulum-v4  16-07-2023 13:31:42        19
# 12      1        13  InvertedDoublePendulum-v4  16-07-2023 13:31:42        20
# 13      1        14  InvertedDoublePendulum-v4  16-07-2023 13:31:42        21
# 14      1        15  InvertedDoublePendulum-v4  16-07-2023 13:31:42        22
#
#     TMCount  RTMCount         e  Ep  EpItr  Done       EpRew       AvgEp  \
# 0         9         0  0.000398   1      9  True   73.196828   73.196828
# 1        10         0  0.000447   1     10  True   81.639682   77.418255
# 2        11         0  0.000497   1     11  True   89.744908   81.527139
# 3        12         0  0.000547   1     12  True   97.304528   85.471486
# 4        13         0  0.000596   1     13  True  103.770579   89.131305
# 5        14         0  0.000646   1     14  True  107.911180   92.261284
# 6        15         0  0.000696   1     15  True  107.730172   94.471125
# 7        16         0  0.000746   1     16  True  107.498763   96.099580
# 8        17         0  0.000795   1     17  True  108.224912   97.446839
# 9        18         0  0.000845   1     18  True  108.365622   98.538717
# 10       19         0  0.000895   1     19  True  108.033517   99.401881
# 11       20         0  0.000944   1     20  True  111.450907  100.405966
# 12       21         0  0.000994   1     21  True  117.028550  101.684627
# 13       22         0  0.001044   1     22  True  123.877044  103.269799
# 14       23         0  0.001093   1     23  True  131.122004  105.126613
#
#       Avg100Ep  AvgLast50Ep  AvgLast10Ep Method
# 0    73.196828    73.196828    73.196828   DDPG
# 1    77.418255    77.418255    77.418255   DDPG
# 2    81.527139    81.527139    81.527139   DDPG
# 3    85.471486    85.471486    85.471486   DDPG
# 4    89.131305    89.131305    89.131305   DDPG
# 5    92.261284    92.261284    92.261284   DDPG
# 6    94.471125    94.471125    94.471125   DDPG
# 7    96.099580    96.099580    96.099580   DDPG
# 8    97.446839    97.446839    97.446839   DDPG
# 9    98.538717    98.538717    98.538717   DDPG
# 10   99.401881    99.401881   102.022386   DDPG
# 11  100.405966   100.405966   105.003509   DDPG
# 12  101.684627   101.684627   107.731873   DDPG
# 13  103.269799   103.269799   110.389125   DDPG
# 14  105.126613   105.126613   113.124267   DDPG

# %%
df=pd.concat([df_comper,df_ddpg])
df.head()
# Out:
#    Trial  LogCount                       Task                 Time  TotalItr  \
# 0      1         1  InvertedDoublePendulum-v4  25-07-2023 16:18:34         9
# 1      1         2  InvertedDoublePendulum-v4  25-07-2023 16:18:35        10
# 2      1         3  InvertedDoublePendulum-v4  25-07-2023 16:18:35        11
# 3      1         4  InvertedDoublePendulum-v4  25-07-2023 16:18:36        12
# 4      1         5  InvertedDoublePendulum-v4  25-07-2023 16:18:37        13
#
#    TMCount  RTMCount         e  Ep  EpItr  Done       EpRew      AvgEp  \
# 0        0         9  0.000447   1     10  True   82.507769  82.507769
# 1        0        10  0.000497   1     11  True   90.900910  86.704340
# 2        0        11  0.000547   1     12  True   99.042960  90.817213
# 3        0        12  0.000596   1     13  True  106.820898  94.818134
# 4        0        13  0.000646   1     14  True  113.872640  98.629035
#
#     Avg100Ep  AvgLast50Ep  AvgLast10Ep  Method
# 0  82.507769    82.507769    82.507769  COMPER
# 1  86.704340    86.704340    86.704340  COMPER
# 2  90.817213    90.817213    90.817213  COMPER
# 3  94.818134    94.818134    94.818134  COMPER
# 4  98.629035    98.629035    98.629035  COMPER

# %%
df.tail()
# Out:
#        Trial  LogCount                       Task                 Time  \
# 45047      5     45048  InvertedDoublePendulum-v4  16-07-2023 20:48:05
# 45048      5     45049  InvertedDoublePendulum-v4  16-07-2023 20:48:05
# 45049      5     45050  InvertedDoublePendulum-v4  16-07-2023 20:48:05
# 45050      5     45051  InvertedDoublePendulum-v4  16-07-2023 20:48:05
# 45051      5     45052  InvertedDoublePendulum-v4  16-07-2023 20:48:05
#
#        TotalItr  TMCount  RTMCount      e  Ep  EpItr  Done        EpRew  \
# 45047     49997    49998         0  0.999  50    998  True  5181.974292
# 45048     49998    49999         0  0.999  50    999  True  5186.971433
# 45049     49999    50000         0  0.999  50   1000  True  5183.483071
# 45050     50000    50001         0  0.999  50   1001  True  5182.169245
# 45051     50001    50002         0  0.999  51      2  True     9.321496
#
#              AvgEp     Avg100Ep  AvgLast50Ep  AvgLast10Ep Method
# 45047  2345.263772  5034.463822  5144.162511  5183.475687   DDPG
# 45048  2345.326852  5038.410103  5146.670539  5183.412166   DDPG
# 45049  2345.389852  5042.265555  5149.035038  5183.652840   DDPG
# 45050  2345.452821  5046.057909  5151.293749  5183.704715   DDPG
# 45051  2345.400966  4998.084466  5049.969411  4667.135569   DDPG

# %%
fig, axs = plt.subplots(nrows=2,ncols=2)
fig.set_figwidth(15)
fig.set_figheight(10)
sns.lineplot(data=df, x="TotalItr", y="EpRew",hue='Method',ax=axs[0][0])
sns.lineplot(data=df, x="TotalItr", y="Avg100Ep",hue="Method",ax=axs[0][1])
sns.lineplot(data=df, x="TotalItr", y="AvgLast50Ep",hue="Method",ax=axs[1][0])
sns.lineplot(data=df, x="TotalItr", y="AvgLast10Ep",hue="Method",ax=axs[1][1])
# Out:
# <Axes: xlabel='TotalItr', ylabel='AvgLast10Ep'>

# %%
fig, axs = plt.subplots(nrows=2,ncols=2)
fig.set_figwidth(15)
fig.set_figheight(10)
sns.lineplot(data=df, x="TotalItr", y="EpRew",hue='Method',ax=axs[0][0])
sns.lineplot(data=df, x="TotalItr", y="Avg100Ep",hue="Method",ax=axs[0][1])
sns.lineplot(data=df, x="TotalItr", y="AvgLast50Ep",hue="Method",ax=axs[1][0])
sns.lineplot(data=df, x="TotalItr", y="AvgLast10Ep",hue="Method",ax=axs[1][1])
# Out:
# <Axes: xlabel='TotalItr', ylabel='AvgLast10Ep'>

# %%
path ='COMPER_DDPG/data/'+env+'/eval/progress.json'
df_comper_eval = pd.read_json(path,lines=True)
df_comper_eval["Method"]="COMPER"
#df_comper_eval=df_comper_eval[df_comper_eval["Trial"]==1]
print(df_comper_eval.shape)
df_comper_eval.head()
# Out:
# (50, 6)
#    Trial                 Time                       Task    Int  EvalAvgRew  \
# 0      1  25-07-2023 18:26:52  InvertedDoublePendulum-v4   5000   22.909732
# 1      1  25-07-2023 20:35:21  InvertedDoublePendulum-v4  10000   41.704175
# 2      1  25-07-2023 22:44:53  InvertedDoublePendulum-v4  15000   51.234430
# 3      1  26-07-2023 00:53:45  InvertedDoublePendulum-v4  20000   32.283914
# 4      1  26-07-2023 03:01:40  InvertedDoublePendulum-v4  25000   46.367033
#
#    Method
# 0  COMPER
# 1  COMPER
# 2  COMPER
# 3  COMPER
# 4  COMPER

# %%
df_comper_eval.describe()
# Out:
#            Trial           Int  EvalAvgRew
# count  50.000000     50.000000   50.000000
# mean    3.000000  27500.000000   38.022973
# std     1.428571  14507.211437   10.368372
# min     1.000000   5000.000000   17.966520
# 25%     2.000000  15000.000000   32.155164
# 50%     3.000000  27500.000000   41.451650
# 75%     4.000000  40000.000000   46.262874
# max     5.000000  50000.000000   51.411897

# %%
path ='DPPG/data/'+env+'/eval/progress.json'
df_ddpg_eval = pd.read_json(path,lines=True)
#df_ddpg_eval=df_ddpg_eval[df_ddpg_eval["Trial"]==1]
df_ddpg_eval["Method"]="DDPG"
print(df_ddpg_eval.shape)
df_ddpg_eval.head()
# Out:
# (50, 6)
#    Trial                 Time                       Task    Int  EvalAvgRew  \
# 0      1  16-07-2023 13:39:14  InvertedDoublePendulum-v4   5000   22.847927
# 1      1  16-07-2023 13:47:03  InvertedDoublePendulum-v4  10000   46.302272
# 2      1  16-07-2023 13:55:07  InvertedDoublePendulum-v4  15000   32.160639
# 3      1  16-07-2023 14:03:24  InvertedDoublePendulum-v4  20000   37.063373
# 4      1  16-07-2023 14:11:58  InvertedDoublePendulum-v4  25000   32.287607
#
#   Method
# 0   DDPG
# 1   DDPG
# 2   DDPG
# 3   DDPG
# 4   DDPG

# %%
df_ddpg_eval.describe()
# Out:
#            Trial           Int  EvalAvgRew
# count  50.000000     50.000000   50.000000
# mean    3.000000  27500.000000   44.020660
# std     1.428571  14507.211437    7.488826
# min     1.000000   5000.000000   22.847927
# 25%     2.000000  15000.000000   37.015614
# 50%     3.000000  27500.000000   46.292743
# 75%     4.000000  40000.000000   51.184073
# max     5.000000  50000.000000   51.444877

# %%
df_eval=pd.concat([df_comper_eval,df_ddpg_eval])
df_eval.rename(columns = {'Int':'Itr'}, inplace = True)

# %%
sns.lineplot(data=df_eval, x="Itr", y="EvalAvgRew",hue='Method')
# Out:
# <Axes: xlabel='Itr', ylabel='EvalAvgRew'>
