# %% [markdown]
# ## FALTAM LOGS DE 2 EXPERIMENTOS PARA O COMPER-DDPG

# %%
import matplotlib.pyplot as plt
import pandas as pd
import json
import os
import seaborn as sns
from numpy import median
import numpy as np
# %matplotlib inline

# %%
env='InvertedDoublePendulum-v4'

# %%
# !echo $PYTHONPATH
# Out:
# /home/daniel/COMPER-GYM-RESULTS

# %%
df_comper = pd.DataFrame()
for i in range(1,4):
  path ='COMPER_DDPG/data/'+env+'/train/trial'+str(i)+'/progress.json'
  aux = pd.read_json(path,lines=True)    
  df_comper = pd.concat([df_comper,aux])
df_comper["Method"]="COMPER"
#df_comper = df_comper.set_index(["Trial"])

print(df_comper.shape)
# Out:
# (40231, 17)

# %%
df_ddpg = pd.DataFrame()
for i in range(1,6):
  path ='DPPG/data/'+env+'/train/trial'+str(i)+'/progress.json'
  aux = pd.read_json(path,lines=True)    
  df_ddpg = pd.concat([df_ddpg,aux])
df_ddpg["Method"]="DDPG"
#df_ddpg = df_ddpg.set_index(["Trial"])
print(df_ddpg.shape)

#/home/daniel/COMPER-GYM-RESULTS/DPPG/data/Ant-v4/train/trial1/progress.json
# Out:
# (66572, 17)

# %%
df_comper.head(15)
# Out:
#     Trial  LogCount                       Task                 Time  TotalItr  \
# 0       1         1  InvertedDoublePendulum-v4  07-06-2023 14:34:04        10
# 1       1         2  InvertedDoublePendulum-v4  07-06-2023 14:34:07        15
# 2       1         3  InvertedDoublePendulum-v4  07-06-2023 14:34:10        19
# 3       1         4  InvertedDoublePendulum-v4  07-06-2023 14:34:12        23
# 4       1         5  InvertedDoublePendulum-v4  07-06-2023 14:34:14        26
# 5       1         6  InvertedDoublePendulum-v4  07-06-2023 14:34:17        30
# 6       1         7  InvertedDoublePendulum-v4  07-06-2023 14:34:20        34
# 7       1         8  InvertedDoublePendulum-v4  07-06-2023 14:34:22        37
# 8       1         9  InvertedDoublePendulum-v4  07-06-2023 14:34:25        40
# 9       1        10  InvertedDoublePendulum-v4  07-06-2023 14:34:28        44
# 10      1        11  InvertedDoublePendulum-v4  07-06-2023 14:34:31        48
# 11      1        12  InvertedDoublePendulum-v4  07-06-2023 14:34:34        51
# 12      1        13  InvertedDoublePendulum-v4  07-06-2023 14:34:37        54
# 13      1        14  InvertedDoublePendulum-v4  07-06-2023 14:34:40        57
# 14      1        15  InvertedDoublePendulum-v4  07-06-2023 14:34:44        61
#
#     TMCount  RTMCount         e  Ep  EpItr  Done      EpRew      AvgEp  \
# 0         0        10  0.000497   1     11  True  91.811683  91.811683
# 1         0        15  0.000746   2      6  True  45.593252  68.702468
# 2         0        19  0.000944   3      5  True  35.739890  57.714942
# 3         0        23  0.001143   4      5  True  35.381588  52.131603
# 4         0        26  0.001292   5      4  True  26.950813  47.095445
# 5         0        30  0.001491   6      5  True  35.131270  45.101416
# 6         0        34  0.001690   7      5  True  35.235584  43.692011
# 7         0        37  0.001839   8      4  True  26.861845  41.588241
# 8         0        40  0.001988   9      4  True  26.821756  39.947520
# 9         0        44  0.002187  10      5  True  35.170444  39.469813
# 10        0        48  0.002386  11      5  True  35.210252  39.082580
# 11        0        51  0.002535  12      4  True  26.897454  38.067153
# 12        0        54  0.002684  13      4  True  26.917545  37.209490
# 13        0        57  0.002833  14      4  True  26.791173  36.465325
# 14        0        61  0.003032  15      5  True  35.256538  36.384739
#
#      Avg100Ep  AvgLast50Ep  AvgLast10Ep  Method
# 
avg100Ep  AvgLast50Ep  AvgLast10Ep Method
# 0   72.795020    72.795020    72.795020   DDPG
# 1   63.491772    63.491772    63.491772   DDPG
# 2   54.350648    54.350648    54.350648   DDPG
# 3   49.691042    49.691042    49.691042   DDPG
# 4   46.807928    46.807928    46.807928   DDPG
# 5   44.881116    44.881116    44.881116   DDPG
# 6   43.526193    43.526193    43.526193   DDPG
# 7   41.450465    41.450465    41.450465   DDPG
# 8   40.768884    40.768884    40.768884   DDPG
# 9   39.377605    39.377605    39.377605   DDPG
# 10  38.234222    38.234222    34.778142   DDPG
# 11  37.288849    37.288849    32.048265   DDPG
# 12  36.479565    36.479565    31.118241   DDPG
# 13  36.383995    36.383995    31.061176   DDPG
# 14  36.324199    36.324199    31.082334   DDPG

# %%
df=pd.concat([df_comper,df_ddpg])
df.head()
# Out:
#    Trial  LogCount                       Task                 Time  TotalItr  \
# 0      1         1  InvertedDoublePendulum-v4  07-06-2023 14:34:04        10
# 1      1         2  InvertedDoublePendulum-v4  07-06-2023 14:34:07        15
# 2      1         3  InvertedDoublePendulum-v4  07-06-2023 14:34:10        19
# 3      1         4  InvertedDoublePendulum-v4  07-06-2023 14:34:12        23
# 4      1         5  InvertedDoublePendulum-v4  07-06-2023 14:34:14        26
#
#    TMCount  RTMCount         e  Ep  EpItr  Done      EpRew      AvgEp  \
# 0        0        10  0.000497   1     11  True  91.811683  91.811683
# 1        0        15  0.000746   2      6  True  45.593252  68.702468
# 2        0        19  0.000944   3      5  True  35.739890  57.714942
# 3        0        23  0.001143   4      5  True  35.381588  52.131603
# 4        0        26  0.001292   5      4  True  26.950813  47.095445
#
#     Avg100Ep  AvgLast50Ep  AvgLast10Ep  Method
# 0  91.811683    91.811683    91.811683  COMPER
# 1  68.702468    68.702468    68.702468  COMPER
# 2  57.714942    57.714942    57.714942  COMPER
# 3  52.131603    52.131603    52.131603  COMPER
# 4  47.095445    47.095445    47.095445  COMPER

# %%
df.tail()
# Out:
#        Trial  LogCount                       Task                 Time  \
# 13632      5     13633  InvertedDoublePendulum-v4  17-06-2023 23:44:55
# 13633      5     13634  InvertedDoublePendulum-v4  17-06-2023 23:44:55
# 13634      5     13635  InvertedDoublePendulum-v4  17-06-2023 23:44:56
# 13635      5     13636  InvertedDoublePendulum-v4  17-06-2023 23:44:56
# 13636      5     13637  InvertedDoublePendulum-v4  17-06-2023 23:44:56
#
#        TotalItr  TMCount  RTMCount      e     Ep  EpItr  Done      EpRew  \
# 13632     49990    49991         0  0.999  13451      5  True  35.386752
# 13633     49993    49994         0  0.999  13452      4  True  26.876735
# 13634     49996    49997         0  0.999  13453      4  True  26.833922
# 13635     50000    50001         0  0.999  13454      5  True  35.295910
# 13636     50001    50002         0  0.999  13455      2  True   9.177127
#
#            AvgEp   Avg100Ep  AvgLast50Ep  AvgLast10Ep Method
# 13632  32.899151  32.012863    30.921688    31.050951   DDPG
# 13633  32.898709  31.923584    30.752386    31.052530   DDPG
# 13634  32.898265  31.834039    30.576603    30.216813   DDPG
# 13635  32.898440  31.829289    30.574068    31.053754   DDPG
# 13636  32.896701  31.562825    30.219243    28.455897   DDPG

# %%
fig, axs = plt.subplots(nrows=2,ncols=2)
fig.set_figwidth(15)
fig.set_figheight(10)
sns.scatterplot(data=df, x="TotalItr", y="EpRew", hue="Method",ax=axs[0][0])
sns.scatterplot(data=df, x="TotalItr", y="Avg100Ep", hue="Method",ax=axs[0][1])
sns.scatterplot(data=df, x="TotalItr", y="AvgLast50Ep", hue="Method",ax=axs[1][0])
sns.scatterplot(data=df, x="TotalItr", y="AvgLast10Ep", hue="Method",ax=axs[1][1])
# Out:
# <Axes: xlabel='TotalItr', ylabel='AvgLast10Ep'>

# %%
fig, axs = plt.subplots(nrows=2,ncols=2)
fig.set_figwidth(15)
fig.set_figheight(10)
sns.lineplot(data=df, x="TotalItr", y="EpRew",hue='Method',ax=axs[0][0])
sns.lineplot(data=df, x="TotalItr", y="Avg100Ep",hue="Method",ax=axs[0][1])
sns.lineplot(data=df, x="TotalItr", y="AvgLast50Ep",hue="Method",ax=axs[1][0])
sns.lineplot(data=df, x="TotalItr", y="AvgLast10Ep",hue="Method",ax=axs[1][1])
# Out:
# <Axes: xlabel='TotalItr', ylabel='AvgLast10Ep'>

# %%
path ='COMPER_DDPG/data/'+env+'/eval/progress.json'
df_comper_eval = pd.read_json(path,lines=True)
df_comper_eval["Method"]="COMPER"
#df_comper_eval=df_comper_eval[df_comper_eval["Trial"]==1]
print(df_comper_eval.shape)
df_comper_eval.head()
# Out:
# (50, 6)
#    Trial                 Time                       Task    Int  EvalAvgRew  \
# 0      1  07-06-2023 16:18:54  InvertedDoublePendulum-v4   5000   18.010130
# 1      1  07-06-2023 18:08:43  InvertedDoublePendulum-v4  10000   18.058909
# 2      1  07-06-2023 20:04:26  InvertedDoublePendulum-v4  15000   18.057574
# 3      1  07-06-2023 22:03:49  InvertedDoublePendulum-v4  20000   22.382416
# 4      1  08-06-2023 00:05:16  InvertedDoublePendulum-v4  25000   22.327287
#
#    Method
# 0  COMPER
# 1  COMPER
# 2  COMPER
# 3  COMPER
# 4  COMPER

# %%
df_comper_eval.describe()
# Out:
#            Trial           Int  EvalAvgRew
# count  50.000000     50.000000   50.000000
# mean    3.000000  27500.000000   19.605786
# std     1.428571  14507.211437    2.097319
# min     1.000000   5000.000000   17.996097
# 25%     2.000000  15000.000000   18.048527
# 50%     3.000000  27500.000000   18.072529
# 75%     4.000000  40000.000000   22.359565
# max     5.000000  50000.000000   22.407948

# %%
path ='DPPG/data/'+env+'/eval/progress.json'
df_ddpg_eval = pd.read_json(path,lines=True)
#df_ddpg_eval=df_ddpg_eval[df_ddpg_eval["Trial"]==1]
df_ddpg_eval["Method"]="DDPG"
print(df_ddpg_eval.shape)
df_ddpg_eval.head()
# Out:
# (50, 6)
#    Trial                 Time                       Task    Int  EvalAvgRew  \
# 0      1  17-06-2023 16:28:39  InvertedDoublePendulum-v4   5000   22.375970
# 1      1  17-06-2023 16:36:01  InvertedDoublePendulum-v4  10000   18.038377
# 2      1  17-06-2023 16:43:47  InvertedDoublePendulum-v4  15000   18.036031
# 3      1  17-06-2023 16:51:54  InvertedDoublePendulum-v4  20000   18.080893
# 4      1  17-06-2023 17:00:22  InvertedDoublePendulum-v4  25000   22.379434
#
#   Method
# 0   DDPG
# 1   DDPG
# 2   DDPG
# 3   DDPG
# 4   DDPG

# %%
df_ddpg_eval.describe()
# Out:
#            Trial           Int  EvalAvgRew
# count  50.000000     50.000000   50.000000
# mean    3.000000  27500.000000   20.031591
# std     1.428571  14507.211437    2.176655
# min     1.000000   5000.000000   17.983742
# 25%     2.000000  15000.000000   18.046630
# 50%     3.000000  27500.000000   18.079703
# 75%     4.000000  40000.000000   22.361943
# max     5.000000  50000.000000   22.403525

# %%
df_eval=pd.concat([df_comper_eval,df_ddpg_eval])
df_eval.rename(columns = {'Int':'Itr'}, inplace = True)

# %%
sns.lineplot(data=df_eval, x="Itr", y="EvalAvgRew",hue='Method')
# Out:
# <Axes: xlabel='Itr', ylabel='EvalAvgRew'>
