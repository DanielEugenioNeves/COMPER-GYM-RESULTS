# %%
import matplotlib.pyplot as plt
import pandas as pd
import json
import os
import seaborn as sns
from numpy import median
import numpy as np
# %matplotlib inline

# %%
env='HalfCheetah-v4'

# %%
# !echo $PYTHONPATH
# Out:
# /home/daniel/COMPER-GYM-RESULTS

# %%
df_comper = pd.DataFrame()
for i in range(1,6):
  path ='COMPER_DDPG/data/'+env+'/train/trial'+str(i)+'/progress.json'
  aux = pd.read_json(path,lines=True)    
  df_comper = pd.concat([df_comper,aux])
df_comper["Method"]="COMPER"
#df_comper = df_comper.set_index(["Trial"])

print(df_comper.shape)
# Out:
# (1255, 17)

# %%
df_ddpg = pd.DataFrame()
for i in range(1,6):
  path ='DPPG/data/'+env+'/train/trial'+str(i)+'/progress.json'
  aux = pd.read_json(path,lines=True)    
  df_ddpg = pd.concat([df_ddpg,aux])
df_ddpg["Method"]="DDPG"
#df_ddpg = df_ddpg.set_index(["Trial"])
print(df_ddpg.shape)

#/home/daniel/COMPER-GYM-RESULTS/DPPG/data/Ant-v4/train/trial1/progress.json
# Out:
# (1255, 17)

# %%
df_comper.head(15)
# Out:
#     Trial  LogCount            Task                 Time  TotalItr  TMCount  \
# 0       1         1  HalfCheetah-v4  31-05-2023 13:29:48       200        0
# 1       1         2  HalfCheetah-v4  31-05-2023 13:34:32       400        0
# 2       1         3  HalfCheetah-v4  31-05-2023 13:39:20       600        0
# 3       1         4  HalfCheetah-v4  31-05-2023 13:44:13       800        0
# 4       1         5  HalfCheetah-v4  31-05-2023 13:49:04      1000        0
# 5       1         6  HalfCheetah-v4  31-05-2023 13:53:54      1200        0
# 6       1         7  HalfCheetah-v4  31-05-2023 13:58:46      1400        0
# 7       1         8  HalfCheetah-v4  31-05-2023 14:03:39      1600        0
# 8       1         9  HalfCheetah-v4  31-05-2023 14:08:26      1800        0
# 9       1        10  HalfCheetah-v4  31-05-2023 14:13:19      2000        0
# 10      1        11  HalfCheetah-v4  31-05-2023 14:18:11      2200        0
# 11      1        12  HalfCheetah-v4  31-05-2023 14:22:57      2400        0
# 12      1        13  HalfCheetah-v4  31-05-2023 14:27:49      2600        0
# 13      1        14  HalfCheetah-v4  31-05-2023 14:32:42      2800        0
# 14      1        15  HalfCheetah-v4  31-05-2023 14:37:30      3000        0
#
#     RTMCount         e  Ep  EpItr   Done       EpRew       AvgEp    Avg100Ep  \
# 0        200  0.009941   1    201  False  -47.979149  -47.979149  -47.979149
# 1        400  0.019882   1    401  False -119.023620  -83.501385  -83.501385
# 2        600  0.029822   1    601  False -158.078271 -108.360347 -108.360347
# 3        800  0.039763   1    801  False -203.233069 -132.078527 -132.078527
# 4       1000  0.049704   1   1001  False -261.404415 -157.943705 -157.943705
# 5       1200  0.059645   1   1201  False -306.255229 -182.662292 -182.662292
# 6       1400  0.069586   1   1401  False -334.442461 -204.345173 -204.345173
# 7       1600  0.079526   1   1601  False -348.579371 -222.374448 -222.374448
# 8       1800  0.089467   1   1801  False -388.791189 -240.865197 -240.865197
# 9       2000  0.099408   1   2001  False -449.399591 -261.718637 -261.718637
# 10      2200  0.109349   1   2201  False -491.566027 -282.613854 -282.613854
# 11      2400  0.119290   1   2401  False -537.925216 -303.889801 -303.889801
# 12      2600  0.129230   1   2601  False -590.182491 -325.912315 -325.912315
# 13      2800  0.139171   1   2801  False -625.400767 -347.304348 -347.304348
# 14      3000  0.149112   1   3001  False -655.858672 -367.874636 -367.874636
#
#     AvgLast50Ep  AvgLast10Ep  Method
# 0    -47.979149   -47.979149  COMPER
# 1    -83.501385   -83.501385  COMPER
# 2   -108.360347  -108.360347  COMPER
# 3   -132.078527  -132.078527  COMPER
# 4   -157.943705  -157.943705  COMPER
# 5   -182.662292  -182.662292  COMPER
# 6   -204.345173  -204.345173  COMPER
# 7   -222.374448  -222.374448  COMPER
# 8   -240.865197  -240.865197  COMPER
# 9   -261.718637  -261.718637  COMPER
# 10  -282.613854  -306.077324  COMPER
# 11  -303.889801  -347.967484  COMPER
# 12  -325.912315  -391.177906  COMPER
# 13  -347.304348  -433.394676  COMPER
# 14  -367.874636  -472.840101  COMPER

# %%
df_ddpg.head(15)
# Out:
#     Trial  LogCount            Task                 Time  TotalItr  TMCount  \
# 0       1         1  HalfCheetah-v4  16-06-2023 18:27:36       200      201
# 1       1         2  HalfCheetah-v4  16-06-2023 18:27:54       400      401
# 2       1         3  HalfCheetah-v4  16-06-2023 18:28:12       600      601
# 3       1         4  HalfCheetah-v4  16-06-2023 18:28:31       800      801
# 4       1         5  HalfCheetah-v4  16-06-2023 18:28:50      1000     1001
# 5       1         6  HalfCheetah-v4  16-06-2023 18:29:08      1200     1201
# 6       1         7  HalfCheetah-v4  16-06-2023 18:29:26      1400     1401
# 7       1         8  HalfCheetah-v4  16-06-2023 18:29:44      1600     1601
# 8       1         9  HalfCheetah-v4  16-06-2023 18:30:02      1800     1801
# 9       1        10  HalfCheetah-v4  16-06-2023 18:30:19      2000     2001
# 10      1        11  HalfCheetah-v4  16-06-2023 18:30:37      2200     2201
# 11      1        12  HalfCheetah-v4  16-06-2023 18:30:55      2400     2401
# 12      1        13  HalfCheetah-v4  16-06-2023 18:31:13      2600     2601
# 13      1        14  HalfCheetah-v4  16-06-2023 18:31:31      2800     2801
# 14      1        15  HalfCheetah-v4  16-06-2023 18:31:49      3000     3001
#
#     RTMCount         e  Ep  EpItr   Done       EpRew       AvgEp    Avg100Ep  \
# 0          0  0.009941   1    201  False  -25.095469  -25.095469  -25.095469
# 1          0  0.019882   1    401  False  -72.929752  -49.012611  -49.012611
# 2          0  0.029822   1    601  False -194.480296  -97.501839  -97.501839
# 3          0  0.039763   1    801  False -263.596463 -139.025495 -139.025495
# 4          0  0.049704   1   1001  False -317.711508 -174.762698 -174.762698
# 5          0  0.059645   1   1201  False -384.007116 -209.636767 -209.636767
# 6          0  0.069586   1   1401  False -442.523396 -242.906286 -242.906286
# 7          0  0.079526   1   1601  False -496.990892 -274.666861 -274.666861
# 8          0  0.089467   1   1801  False -533.946141 -303.475670 -303.475670
# 9          0  0.099408   1   2001  False -581.323523 -331.260456 -331.260456
# 10         0  0.109349   1   2201  False -616.204514 -357.164461 -357.164461
# 11         0  0.119290   1   2401  False -671.628231 -383.369775 -383.369775
# 12         0  0.129230   1   2601  False -729.318103 -409.981185 -409.981185
# 13         0  0.139171   1   2801  False -769.230683 -435.641863 -435.641863
# 14         0  0.149112   1   3001  False -839.965258 -462.596756 -462.596756
#
#     AvgLast50Ep  AvgLast10Ep Method
# 0    -25.095469   -25.095469   DDPG
# 1    -49.012611   -49.012611   DDPG
# 2    -97.501839   -97.501839   DDPG
# 3   -139.025495  -139.025495   DDPG
# 4   -174.762698  -174.762698   DDPG
# 5   -209.636767  -209.636767   DDPG
# 6   -242.906286  -242.906286   DDPG
# 7   -274.666861  -274.666861   DDPG
# 8   -303.475670  -303.475670   DDPG
# 9   -331.260456  -331.260456   DDPG
# 10  -357.164461  -390.371360   DDPG
# 11  -383.369775  -450.241208   DDPG
# 12  -409.981185  -503.724989   DDPG
# 13  -435.641863  -554.288411   DDPG
# 14  -462.596756  -606.513786   DDPG

# %%
df=pd.concat([df_comper,df_ddpg])
df.head()
# Out:
#    Trial  LogCount            Task                 Time  TotalItr  TMCount  \
# 0      1         1  HalfCheetah-v4  31-05-2023 13:29:48       200        0
# 1      1         2  HalfCheetah-v4  31-05-2023 13:34:32       400        0
# 2      1         3  HalfCheetah-v4  31-05-2023 13:39:20       600        0
# 3      1         4  HalfCheetah-v4  31-05-2023 13:44:13       800        0
# 4      1         5  HalfCheetah-v4  31-05-2023 13:49:04      1000        0
#
#    RTMCount         e  Ep  EpItr   Done       EpRew       AvgEp    Avg100Ep  \
# 0       200  0.009941   1    201  False  -47.979149  -47.979149  -47.979149
# 1       400  0.019882   1    401  False -119.023620  -83.501385  -83.501385
# 2       600  0.029822   1    601  False -158.078271 -108.360347 -108.360347
# 3       800  0.039763   1    801  False -203.233069 -132.078527 -132.078527
# 4      1000  0.049704   1   1001  False -261.404415 -157.943705 -157.943705
#
#    AvgLast50Ep  AvgLast10Ep  Method
# 0   -47.979149   -47.979149  COMPER
# 1   -83.501385   -83.501385  COMPER
# 2  -108.360347  -108.360347  COMPER
# 3  -132.078527  -132.078527  COMPER
# 4  -157.943705  -157.943705  COMPER

# %%
df.tail()
# Out:
#      Trial  LogCount            Task                 Time  TotalItr  TMCount  \
# 246      5       247  HalfCheetah-v4  17-06-2023 02:26:21     49400    49401
# 247      5       248  HalfCheetah-v4  17-06-2023 02:26:48     49600    49601
# 248      5       249  HalfCheetah-v4  17-06-2023 02:27:16     49800    49801
# 249      5       250  HalfCheetah-v4  17-06-2023 02:27:45     50000    50001
# 250      5       251  HalfCheetah-v4  17-06-2023 02:27:45     50001    50002
#
#      RTMCount      e  Ep  EpItr   Done        EpRew       AvgEp    Avg100Ep  \
# 246         0  0.999   1  49401  False -3274.757035  512.163697  903.475452
# 247         0  0.999   1  49601  False -3343.468422  496.616794  825.201761
# 248         0  0.999   1  49801  False -3393.357810  480.994406  745.809427
# 249         0  0.999   1  50001   True -3435.381324  465.328903  665.287963
# 250         0  0.999   2      2   True    -0.782355  463.471886  618.824708
#
#      AvgLast50Ep  AvgLast10Ep Method
# 246 -1225.782280 -2838.106068   DDPG
# 247 -1312.103805 -2924.419058   DDPG
# 248 -1397.143306 -3011.200947   DDPG
# 249 -1480.862501 -3096.726378   DDPG
# 250 -1493.696307 -2830.512418   DDPG

# %%
fig, axs = plt.subplots(nrows=2,ncols=2)
fig.set_figwidth(15)
fig.set_figheight(10)
sns.lineplot(data=df, x="TotalItr", y="EpRew",hue='Method',ax=axs[0][0])
sns.lineplot(data=df, x="TotalItr", y="Avg100Ep",hue="Method",ax=axs[0][1])
sns.lineplot(data=df, x="TotalItr", y="AvgLast50Ep",hue="Method",ax=axs[1][0])
sns.lineplot(data=df, x="TotalItr", y="AvgLast10Ep",hue="Method",ax=axs[1][1])
# Out:
# <Axes: xlabel='TotalItr', ylabel='AvgLast10Ep'>

# %%
path ='COMPER_DDPG/data/'+env+'/eval/progress.json'
df_comper_eval = pd.read_json(path,lines=True)
df_comper_eval["Method"]="COMPER"
#df_comper_eval=df_comper_eval[df_comper_eval["Trial"]==1]
print(df_comper_eval.shape)
df_comper_eval.head()
# Out:
# (50, 6)
#    Trial                 Time            Task    Itr  EvalAvgRew  Method
# 0      4  30-05-2023 17:59:09  HalfCheetah-v4   5000   -3.470749  COMPER
# 1      4  30-05-2023 19:54:10  HalfCheetah-v4  10000   -3.155920  COMPER
# 2      4  30-05-2023 21:51:38  HalfCheetah-v4  15000   -0.242363  COMPER
# 3      4  30-05-2023 23:49:13  HalfCheetah-v4  20000    0.382928  COMPER
# 4      4  31-05-2023 01:45:27  HalfCheetah-v4  25000   -0.490035  COMPER

# %%
df_comper_eval.describe()
# Out:
#            Trial           Itr  EvalAvgRew
# count  50.000000     50.000000   50.000000
# mean    3.000000  27500.000000   -2.428146
# std     1.428571  14507.211437    1.719223
# min     1.000000   5000.000000   -6.281670
# 25%     2.000000  15000.000000   -3.682992
# 50%     3.000000  27500.000000   -2.719892
# 75%     4.000000  40000.000000   -1.017297
# max     5.000000  50000.000000    0.775289

# %%
path ='DPPG/data/'+env+'/eval/progress.json'
df_ddpg_eval = pd.read_json(path,lines=True)
#df_ddpg_eval=df_ddpg_eval[df_ddpg_eval["Trial"]==1]
df_ddpg_eval["Method"]="DDPG"
print(df_ddpg_eval.shape)
df_ddpg_eval.head()
# Out:
# (50, 6)
#    Trial                 Time            Task    Itr  EvalAvgRew Method
# 0      1  16-06-2023 18:34:54  HalfCheetah-v4   5000   -5.204233   DDPG
# 1      1  16-06-2023 18:42:57  HalfCheetah-v4  10000   -0.610937   DDPG
# 2      1  16-06-2023 18:51:22  HalfCheetah-v4  15000   -0.331783   DDPG
# 3      1  16-06-2023 19:00:19  HalfCheetah-v4  20000   -0.617961   DDPG
# 4      1  16-06-2023 19:10:04  HalfCheetah-v4  25000   -0.076118   DDPG

# %%
df_ddpg_eval.describe()
# Out:
#            Trial           Itr  EvalAvgRew
# count  50.000000     50.000000   50.000000
# mean    3.000000  27500.000000   -0.942306
# std     1.428571  14507.211437    1.348152
# min     1.000000   5000.000000   -5.204233
# 25%     2.000000  15000.000000   -1.528026
# 50%     3.000000  27500.000000   -0.613147
# 75%     4.000000  40000.000000   -0.241639
# max     5.000000  50000.000000    1.555411

# %%
df_eval=pd.concat([df_comper_eval,df_ddpg_eval])

# %%
sns.lineplot(data=df_eval, x="Itr", y="EvalAvgRew",hue='Method')
# Out:
# <Axes: xlabel='Itr', ylabel='EvalAvgRew'>
