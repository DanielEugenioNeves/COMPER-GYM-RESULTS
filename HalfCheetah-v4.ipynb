# %%
import matplotlib.pyplot as plt
import pandas as pd
import json
import os
import seaborn as sns
from numpy import median
import numpy as np
# %matplotlib inline

# %%
env='HalfCheetah-v4'

# %%
# !echo $PYTHONPATH
# Out:
# /home/daniel/COMPER-GYM-RESULTS

# %%
df_comper = pd.DataFrame()
for i in range(1,6):
  path ='COMPER_DDPG/data/'+env+'/train/trial'+str(i)+'/progress.json'
  aux = pd.read_json(path,lines=True)    
  df_comper = pd.concat([df_comper,aux])
df_comper["Method"]="COMPER"
#df_comper = df_comper.set_index(["Trial"])

print(df_comper.shape)
# Out:
# (2003, 17)

# %%
df_ddpg = pd.DataFrame()
for i in range(1,6):
  path ='DPPG/data/'+env+'/train/trial'+str(i)+'/progress.json'
  aux = pd.read_json(path,lines=True)    
  df_ddpg = pd.concat([df_ddpg,aux])
df_ddpg["Method"]="DDPG"
#df_ddpg = df_ddpg.set_index(["Trial"])
print(df_ddpg.shape)

#/home/daniel/COMPER-GYM-RESULTS/DPPG/data/Ant-v4/train/trial1/progress.json
# Out:
# (1255, 17)

# %%
df_comper.head(15)
# Out:
#     Trial  LogCount            Task                 Time  TotalItr  TMCount  \
# 0       1         1  HalfCheetah-v4  11-07-2023 23:14:47       200      201
# 1       1         2  HalfCheetah-v4  11-07-2023 23:15:05       400      401
# 2       1         3  HalfCheetah-v4  11-07-2023 23:15:23       600      601
# 3       1         4  HalfCheetah-v4  11-07-2023 23:15:42       800      801
# 4       1         5  HalfCheetah-v4  11-07-2023 23:16:00      1000     1001
# 5       1         6  HalfCheetah-v4  11-07-2023 23:16:19      1200     1201
# 6       1         7  HalfCheetah-v4  11-07-2023 23:16:38      1400     1401
# 7       1         8  HalfCheetah-v4  11-07-2023 23:16:57      1600     1601
# 8       1         9  HalfCheetah-v4  11-07-2023 23:17:16      1800     1801
# 9       1        10  HalfCheetah-v4  11-07-2023 23:17:36      2000     2001
# 10      1        11  HalfCheetah-v4  11-07-2023 23:17:55      2200     2201
# 11      1        12  HalfCheetah-v4  11-07-2023 23:18:14      2400     2401
# 12      1        13  HalfCheetah-v4  11-07-2023 23:18:34      2600     2601
# 13      1        14  HalfCheetah-v4  11-07-2023 23:18:54      2800     2801
# 14      1        15  HalfCheetah-v4  11-07-2023 23:19:13      3000     3001
#
#     RTMCount         e  Ep  EpItr   Done       EpRew       AvgEp    Avg100Ep  \
# 0          0  0.009941   1    201  False -107.578525 -107.578525 -107.578525
# 1          0  0.019882   1    401  False -134.729259 -121.153892 -121.153892
# 2          0  0.029822   1    601  False -141.262717 -127.856834 -127.856834
# 3          0  0.039763   1    801  False -194.780773 -144.587818 -144.587818
# 4          0  0.049704   1   1001   True -235.623996 -162.795054 -162.795054
# 5          0  0.059645   2    201  False  -48.515635 -143.748484 -143.748484
# 6          0  0.069586   2    401  False  -50.226036 -130.388134 -130.388134
# 7          0  0.079526   2    601  False -110.085319 -127.850283 -127.850283
# 8          0  0.089467   2    801  False -169.187116 -132.443264 -132.443264
# 9          0  0.099408   2   1001   True -236.401605 -142.839098 -142.839098
# 10         0  0.109349   3    201  False  -31.306224 -132.699746 -132.699746
# 11         0  0.119290   3    401  False    7.585211 -121.009333 -121.009333
# 12         0  0.129230   3    601  False  -18.244124 -113.104317 -113.104317
# 13         0  0.139171   3    801  False  -98.761626 -112.079839 -112.079839
# 14         0  0.149112   3   1001   True -192.211641 -117.421959 -117.421959
#
#     AvgLast50Ep  AvgLast10Ep  Method
# 0   -107.578525  -107.578525  COMPER
# 1   -121.153892  -121.153892  COMPER
# 2   -127.856834  -127.856834  COMPER
# 3   -144.587818  -144.587818  COMPER
# 4   -162.795054  -162.795054  COMPER
# 5   -143.748484  -143.748484  COMPER
# 6   -130.388134  -130.388134  COMPER
# 7   -127.850283  -127.850283  COMPER
# 8   -132.443264  -132.443264  COMPER
# 9   -142.839098  -142.839098  COMPER
# 10  -132.699746  -135.211868  COMPER
# 11  -121.009333  -120.980421  COMPER
# 12  -113.104317  -108.678562  COMPER
# 13  -112.079839   -99.076647  COMPER
# 14  -117.421959   -94.735412  COMPER

# %%
df_ddpg.head(15)
# Out:
#     Trial  LogCount            Task                 Time  TotalItr  TMCount  \
# 0       1         1  HalfCheetah-v4  11-07-2023 23:14:47       200      201
# 1       1         2  HalfCheetah-v4  11-07-2023 23:15:05       400      401
# 2       1         3  HalfCheetah-v4  11-07-2023 23:15:23       600      601
# 3       1         4  HalfCheetah-v4  11-07-2023 23:15:42       800      801
# 4       1         5  HalfCheetah-v4  11-07-2023 23:16:00      1000     1001
# 5       1         6  HalfCheetah-v4  11-07-2023 23:16:19      1200     1201
# 6       1         7  HalfCheetah-v4  11-07-2023 23:16:38      1400     1401
# 7       1         8  HalfCheetah-v4  11-07-2023 23:16:57      1600     1601
# 8       1         9  HalfCheetah-v4  11-07-2023 23:17:16      1800     1801
# 9       1        10  HalfCheetah-v4  11-07-2023 23:17:36      2000     2001
# 10      1        11  HalfCheetah-v4  11-07-2023 23:17:55      2200     2201
# 11      1        12  HalfCheetah-v4  11-07-2023 23:18:14      2400     2401
# 12      1        13  HalfCheetah-v4  11-07-2023 23:18:34      2600     2601
# 13      1        14  HalfCheetah-v4  11-07-2023 23:18:54      2800     2801
# 14      1        15  HalfCheetah-v4  11-07-2023 23:19:13      3000     3001
#
#     RTMCount         e  Ep  EpItr   Done       EpRew       AvgEp    Avg100Ep  \
# 0          0  0.009941   1    201  False -107.578525 -107.578525 -107.578525
# 1          0  0.019882   1    401  False -134.729259 -121.153892 -121.153892
# 2          0  0.029822   1    601  False -141.262717 -127.856834 -127.856834
# 3          0  0.039763   1    801  False -194.780773 -144.587818 -144.587818
# 4          0  0.049704   1   1001   True -235.623996 -162.795054 -162.795054
# 5          0  0.059645   2    201  False  -48.515635 -143.748484 -143.748484
# 6          0  0.069586   2    401  False  -50.226036 -130.388134 -130.388134
# 7          0  0.079526   2    601  False -110.085319 -127.850283 -127.850283
# 8          0  0.089467   2    801  False -169.187116 -132.443264 -132.443264
# 9          0  0.099408   2   1001   True -236.401605 -142.839098 -142.839098
# 10         0  0.109349   3    201  False  -31.306224 -132.699746 -132.699746
# 11         0  0.119290   3    401  False    7.585211 -121.009333 -121.009333
# 12         0  0.129230   3    601  False  -18.244124 -113.104317 -113.104317
# 13         0  0.139171   3    801  False  -98.761626 -112.079839 -112.079839
# 14         0  0.149112   3   1001   True -192.211641 -117.421959 -117.421959
#
#     AvgLast50Ep  AvgLast10Ep Method
# 0   -107.578525  -107.578525   DDPG
# 1   -121.153892  -121.153892   DDPG
# 2   -127.856834  -127.856834   DDPG
# 3   -144.587818  -144.587818   DDPG
# 4   -162.795054  -162.795054   DDPG
# 5   -143.748484  -143.748484   DDPG
# 6   -130.388134  -130.388134   DDPG
# 7   -127.850283  -127.850283   DDPG
# 8   -132.443264  -132.443264   DDPG
# 9   -142.839098  -142.839098   DDPG
# 10  -132.699746  -135.211868   DDPG
# 11  -121.009333  -120.980421   DDPG
# 12  -113.104317  -108.678562   DDPG
# 13  -112.079839   -99.076647   DDPG
# 14  -117.421959   -94.735412   DDPG

# %%
df=pd.concat([df_comper,df_ddpg])
df.head()
# Out:
#    Trial  LogCount            Task                 Time  TotalItr  TMCount  \
# 0      1         1  HalfCheetah-v4  11-07-2023 23:14:47       200      201
# 1      1         2  HalfCheetah-v4  11-07-2023 23:15:05       400      401
# 2      1         3  HalfCheetah-v4  11-07-2023 23:15:23       600      601
# 3      1         4  HalfCheetah-v4  11-07-2023 23:15:42       800      801
# 4      1         5  HalfCheetah-v4  11-07-2023 23:16:00      1000     1001
#
#    RTMCount         e  Ep  EpItr   Done       EpRew       AvgEp    Avg100Ep  \
# 0         0  0.009941   1    201  False -107.578525 -107.578525 -107.578525
# 1         0  0.019882   1    401  False -134.729259 -121.153892 -121.153892
# 2         0  0.029822   1    601  False -141.262717 -127.856834 -127.856834
# 3         0  0.039763   1    801  False -194.780773 -144.587818 -144.587818
# 4         0  0.049704   1   1001   True -235.623996 -162.795054 -162.795054
#
#    AvgLast50Ep  AvgLast10Ep  Method
# 0  -107.578525  -107.578525  COMPER
# 1  -121.153892  -121.153892  COMPER
# 2  -127.856834  -127.856834  COMPER
# 3  -144.587818  -144.587818  COMPER
# 4  -162.795054  -162.795054  COMPER

# %%
df.tail()
# Out:
#      Trial  LogCount            Task                 Time  TotalItr  TMCount  \
# 246      5       247  HalfCheetah-v4  12-07-2023 06:43:10     49400    49401
# 247      5       248  HalfCheetah-v4  12-07-2023 06:43:36     49600    49601
# 248      5       249  HalfCheetah-v4  12-07-2023 06:44:01     49800    49801
# 249      5       250  HalfCheetah-v4  12-07-2023 06:44:26     50000    50001
# 250      5       251  HalfCheetah-v4  12-07-2023 06:44:27     50001    50002
#
#      RTMCount      e  Ep  EpItr   Done        EpRew       AvgEp    Avg100Ep  \
# 246         0  0.999  50    401  False   505.633415  436.317152  849.388155
# 247         0  0.999  50    601  False   851.845264  437.992669  848.164624
# 248         0  0.999  50    801  False  1380.908361  441.779479  849.106424
# 249         0  0.999  50   1001   True  1770.345873  447.093744  851.069326
# 250         0  0.999  51      2   True     0.639196  445.315041  848.414813
#
#      AvgLast50Ep  AvgLast10Ep Method
# 246   936.114046  1147.496914   DDPG
# 247   945.389117  1141.291788   DDPG
# 248   956.668167  1158.267116   DDPG
# 249   968.031599  1170.947017   DDPG
# 250   961.008155  1130.346146   DDPG

# %%
fig, axs = plt.subplots(nrows=2,ncols=2)
fig.set_figwidth(15)
fig.set_figheight(10)
sns.lineplot(data=df, x="TotalItr", y="EpRew",hue='Method',ax=axs[0][0])
sns.lineplot(data=df, x="TotalItr", y="Avg100Ep",hue="Method",ax=axs[0][1])
sns.lineplot(data=df, x="TotalItr", y="AvgLast50Ep",hue="Method",ax=axs[1][0])
sns.lineplot(data=df, x="TotalItr", y="AvgLast10Ep",hue="Method",ax=axs[1][1])
# Out:
# <Axes: xlabel='TotalItr', ylabel='AvgLast10Ep'>

# %%
path ='COMPER_DDPG/data/'+env+'/eval/progress.json'
df_comper_eval = pd.read_json(path,lines=True)
df_comper_eval["Method"]="COMPER"
#df_comper_eval=df_comper_eval[df_comper_eval["Trial"]==1]
print(df_comper_eval.shape)
df_comper_eval.head()
# Out:
# (80, 6)
#    Trial                 Time            Task    Int  EvalAvgRew  Method
# 0      1  12-07-2023 15:02:38  HalfCheetah-v4   5000    0.672154  COMPER
# 1      1  12-07-2023 17:14:45  HalfCheetah-v4  10000    0.626019  COMPER
# 2      1  12-07-2023 19:26:47  HalfCheetah-v4  15000    0.099893  COMPER
# 3      1  12-07-2023 21:39:23  HalfCheetah-v4  20000   -1.809298  COMPER
# 4      1  12-07-2023 23:48:44  HalfCheetah-v4  25000    1.003056  COMPER

# %%
df_comper_eval.describe()
# Out:
#            Trial           Int  EvalAvgRew
# count  80.000000     80.000000   80.000000
# mean    3.125000  27500.000000    0.117512
# std     1.625548  14452.015759    1.559765
# min     1.000000   5000.000000   -3.234325
# 25%     2.000000  15000.000000   -0.958934
# 50%     2.500000  27500.000000    0.261708
# 75%     4.250000  40000.000000    1.251830
# max     6.000000  50000.000000    4.082751

# %%
path ='DPPG/data/'+env+'/eval/progress.json'
df_ddpg_eval = pd.read_json(path,lines=True)
#df_ddpg_eval=df_ddpg_eval[df_ddpg_eval["Trial"]==1]
df_ddpg_eval["Method"]="DDPG"
print(df_ddpg_eval.shape)
df_ddpg_eval.head()
# Out:
# (50, 6)
#    Trial                 Time            Task    Int  EvalAvgRew Method
# 0      1  11-07-2023 23:22:27  HalfCheetah-v4   5000    0.819138   DDPG
# 1      1  11-07-2023 23:30:24  HalfCheetah-v4  10000   -0.516756   DDPG
# 2      1  11-07-2023 23:38:41  HalfCheetah-v4  15000    2.751040   DDPG
# 3      1  11-07-2023 23:47:16  HalfCheetah-v4  20000   -0.152538   DDPG
# 4      1  11-07-2023 23:56:10  HalfCheetah-v4  25000   -1.204190   DDPG

# %%
df_ddpg_eval.describe()
# Out:
#            Trial           Int  EvalAvgRew
# count  50.000000     50.000000   50.000000
# mean    3.000000  27500.000000    0.374094
# std     1.428571  14507.211437    1.599204
# min     1.000000   5000.000000   -2.749756
# 25%     2.000000  15000.000000   -0.928333
# 50%     3.000000  27500.000000    0.487719
# 75%     4.000000  40000.000000    1.783329
# max     5.000000  50000.000000    3.046018

# %%
df_eval=pd.concat([df_comper_eval,df_ddpg_eval])

# %%
sns.lineplot(data=df_eval, x="Int", y="EvalAvgRew",hue='Method')
# Out:
# <Axes: xlabel='Int', ylabel='EvalAvgRew'>
